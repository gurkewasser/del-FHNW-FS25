# %%
import os
from PIL import Image

# Folder path
folder_path = "/home/arian/deepLearning/del/data/original/n02056570/"

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".JPEG"):
        image_path = os.path.join(folder_path, filename)
        image = Image.open(image_path)
        
        # Print image properties
        print(f"Filename: {filename}")
        print(f"Format: {image.format}")
        print(f"Size: {image.size}")
        print(f"Mode: {image.mode}")
        print("-" * 30)
        
        # Display the image (optional)
        # image.show()
# Out:
# Filename: n02056570_5361.JPEG
# Format: JPEG
# Size: (1071, 1600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7236.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_633.JPEG
# Format: JPEG
# Size: (1280, 960)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3308.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9339.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9174.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11341.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9148.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9364.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9747.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3320.JPEG
# Format: JPEG
# Size: (550, 366)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10082.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9765.JPEG
# Format: JPEG
# Size: (500, 324)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2145.JPEG
# Format: JPEG
# Size: (1600, 1200)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9722.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3311.JPEG
# Format: JPEG
# Size: (400, 271)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8246.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9785.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9241.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4735.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1675.JPEG
# Format: JPEG
# Size: (300, 262)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8467.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1396.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8710.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_436.JPEG
# Format: JPEG
# Size: (375, 514)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11157.JPEG
# Format: JPEG
# Size: (500, 357)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8229.JPEG
# Format: JPEG
# Size: (356, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9677.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6484.JPEG
# Format: JPEG
# Size: (640, 429)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9490.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8334.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5497.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8964.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8960.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_808.JPEG
# Format: JPEG
# Size: (400, 269)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9969.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11836.JPEG
# Format: JPEG
# Size: (337, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3683.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8655.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8476.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9503.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9630.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11744.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4236.JPEG
# Format: JPEG
# Size: (640, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8303.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2486.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2501.JPEG
# Format: JPEG
# Size: (525, 445)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8541.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10866.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8502.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9585.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9057.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1196.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12231.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8752.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8055.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1323.JPEG
# Format: JPEG
# Size: (320, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7135.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7316.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_26564.JPEG
# Format: JPEG
# Size: (354, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8272.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9262.JPEG
# Format: JPEG
# Size: (363, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8928.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9955.JPEG
# Format: JPEG
# Size: (500, 379)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6057.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4173.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9329.JPEG
# Format: JPEG
# Size: (500, 420)
# Mode: RGB
# ------------------------------
# Filename: n02056570_16268.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7237.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9091.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8337.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10069.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6405.JPEG
# Format: JPEG
# Size: (768, 413)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8206.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9897.JPEG
# Format: JPEG
# Size: (479, 326)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12066.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8390.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3156.JPEG
# Format: JPEG
# Size: (350, 234)
# Mode: RGB
# ------------------------------
# Filename: n02056570_109.JPEG
# Format: JPEG
# Size: (1066, 1600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7282.JPEG
# Format: JPEG
# Size: (800, 534)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8833.JPEG
# Format: JPEG
# Size: (500, 495)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6797.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10076.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8645.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9232.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8197.JPEG
# Format: JPEG
# Size: (500, 376)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8308.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4953.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4942.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9937.JPEG
# Format: JPEG
# Size: (338, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9986.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12542.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1691.JPEG
# Format: JPEG
# Size: (2160, 1440)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1399.JPEG
# Format: JPEG
# Size: (2288, 1712)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9183.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13048.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8929.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7245.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8264.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8181.JPEG
# Format: JPEG
# Size: (357, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_182.JPEG
# Format: JPEG
# Size: (640, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9107.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11355.JPEG
# Format: JPEG
# Size: (500, 369)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3693.JPEG
# Format: JPEG
# Size: (500, 398)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11955.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_741.JPEG
# Format: JPEG
# Size: (462, 308)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4914.JPEG
# Format: JPEG
# Size: (610, 402)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10106.JPEG
# Format: JPEG
# Size: (337, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_998.JPEG
# Format: JPEG
# Size: (600, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9353.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12397.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8243.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1816.JPEG
# Format: JPEG
# Size: (600, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_637.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_140.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5731.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9638.JPEG
# Format: JPEG
# Size: (500, 340)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9984.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8354.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_22961.JPEG
# Format: JPEG
# Size: (343, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7616.JPEG
# Format: JPEG
# Size: (540, 354)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2568.JPEG
# Format: JPEG
# Size: (200, 303)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3796.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7925.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9819.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1971.JPEG
# Format: JPEG
# Size: (332, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9295.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2937.JPEG
# Format: JPEG
# Size: (260, 315)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2781.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7193.JPEG
# Format: JPEG
# Size: (2288, 1712)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8842.JPEG
# Format: JPEG
# Size: (266, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_26427.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9279.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3228.JPEG
# Format: JPEG
# Size: (1024, 685)
# Mode: RGB
# ------------------------------
# Filename: n02056570_19893.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9233.JPEG
# Format: JPEG
# Size: (351, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10103.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11306.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_914.JPEG
# Format: JPEG
# Size: (400, 291)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8200.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8536.JPEG
# Format: JPEG
# Size: (500, 365)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9236.JPEG
# Format: JPEG
# Size: (342, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12953.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_25703.JPEG
# Format: JPEG
# Size: (500, 371)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8702.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9641.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1026.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_20387.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8721.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1441.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7710.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9355.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5172.JPEG
# Format: JPEG
# Size: (1712, 2192)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9944.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5896.JPEG
# Format: JPEG
# Size: (358, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8795.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9501.JPEG
# Format: JPEG
# Size: (500, 379)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9198.JPEG
# Format: JPEG
# Size: (373, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8443.JPEG
# Format: JPEG
# Size: (500, 331)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12951.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8709.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9574.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9634.JPEG
# Format: JPEG
# Size: (336, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_23998.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8336.JPEG
# Format: JPEG
# Size: (327, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9690.JPEG
# Format: JPEG
# Size: (500, 370)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3283.JPEG
# Format: JPEG
# Size: (664, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8521.JPEG
# Format: JPEG
# Size: (352, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5502.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9373.JPEG
# Format: JPEG
# Size: (433, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9773.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1608.JPEG
# Format: JPEG
# Size: (1600, 1200)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7456.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9929.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2419.JPEG
# Format: JPEG
# Size: (340, 519)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8993.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9532.JPEG
# Format: JPEG
# Size: (500, 369)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3303.JPEG
# Format: JPEG
# Size: (612, 459)
# Mode: RGB
# ------------------------------
# Filename: n02056570_63.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8493.JPEG
# Format: JPEG
# Size: (357, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9867.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12851.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3005.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1027.JPEG
# Format: JPEG
# Size: (425, 401)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1348.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8065.JPEG
# Format: JPEG
# Size: (1600, 1200)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8381.JPEG
# Format: JPEG
# Size: (344, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13820.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_23561.JPEG
# Format: JPEG
# Size: (500, 344)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9030.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9982.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4630.JPEG
# Format: JPEG
# Size: (350, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7972.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4121.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8708.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8606.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_24051.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9975.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8720.JPEG
# Format: JPEG
# Size: (297, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_599.JPEG
# Format: JPEG
# Size: (520, 348)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7125.JPEG
# Format: JPEG
# Size: (750, 439)
# Mode: RGB
# ------------------------------
# Filename: n02056570_68.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_749.JPEG
# Format: JPEG
# Size: (1024, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9394.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9140.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9209.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3361.JPEG
# Format: JPEG
# Size: (136, 150)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2825.JPEG
# Format: JPEG
# Size: (500, 368)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1864.JPEG
# Format: JPEG
# Size: (272, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1422.JPEG
# Format: JPEG
# Size: (320, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_26614.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_707.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8412.JPEG
# Format: JPEG
# Size: (500, 386)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3164.JPEG
# Format: JPEG
# Size: (503, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_407.JPEG
# Format: JPEG
# Size: (270, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10146.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9652.JPEG
# Format: JPEG
# Size: (500, 320)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13790.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3239.JPEG
# Format: JPEG
# Size: (400, 267)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8360.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10062.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6839.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12752.JPEG
# Format: JPEG
# Size: (500, 357)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10080.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9405.JPEG
# Format: JPEG
# Size: (328, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_617.JPEG
# Format: JPEG
# Size: (267, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9371.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1038.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5500.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4198.JPEG
# Format: JPEG
# Size: (600, 382)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1447.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8240.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6378.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8561.JPEG
# Format: JPEG
# Size: (384, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9771.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6852.JPEG
# Format: JPEG
# Size: (500, 380)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5587.JPEG
# Format: JPEG
# Size: (640, 427)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8915.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9626.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11626.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4813.JPEG
# Format: JPEG
# Size: (720, 720)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1169.JPEG
# Format: JPEG
# Size: (400, 267)
# Mode: RGB
# ------------------------------
# Filename: n02056570_15798.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5962.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8841.JPEG
# Format: JPEG
# Size: (500, 342)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8364.JPEG
# Format: JPEG
# Size: (331, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8288.JPEG
# Format: JPEG
# Size: (500, 357)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8286.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5298.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9524.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10175.JPEG
# Format: JPEG
# Size: (500, 344)
# Mode: RGB
# ------------------------------
# Filename: n02056570_20693.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7608.JPEG
# Format: JPEG
# Size: (459, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9419.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8737.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8745.JPEG
# Format: JPEG
# Size: (500, 348)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7491.JPEG
# Format: JPEG
# Size: (800, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11140.JPEG
# Format: JPEG
# Size: (336, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_17666.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9745.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_16919.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2608.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3382.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5018.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_824.JPEG
# Format: JPEG
# Size: (410, 266)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4540.JPEG
# Format: JPEG
# Size: (600, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4807.JPEG
# Format: JPEG
# Size: (500, 396)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9367.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7257.JPEG
# Format: JPEG
# Size: (800, 622)
# Mode: RGB
# ------------------------------
# Filename: n02056570_417.JPEG
# Format: JPEG
# Size: (600, 399)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6633.JPEG
# Format: JPEG
# Size: (750, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1018.JPEG
# Format: JPEG
# Size: (400, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10990.JPEG
# Format: JPEG
# Size: (500, 354)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10149.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3302.JPEG
# Format: JPEG
# Size: (364, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4828.JPEG
# Format: JPEG
# Size: (480, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1687.JPEG
# Format: JPEG
# Size: (500, 337)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9108.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9901.JPEG
# Format: JPEG
# Size: (500, 373)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5200.JPEG
# Format: JPEG
# Size: (1600, 1066)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2033.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8641.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_21917.JPEG
# Format: JPEG
# Size: (500, 360)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5193.JPEG
# Format: JPEG
# Size: (262, 350)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8318.JPEG
# Format: JPEG
# Size: (500, 354)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5105.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10108.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9810.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6235.JPEG
# Format: JPEG
# Size: (465, 700)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1346.JPEG
# Format: JPEG
# Size: (600, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5396.JPEG
# Format: JPEG
# Size: (500, 402)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1195.JPEG
# Format: JPEG
# Size: (282, 384)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6379.JPEG
# Format: JPEG
# Size: (470, 700)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11523.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7149.JPEG
# Format: JPEG
# Size: (725, 484)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9976.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13168.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6973.JPEG
# Format: JPEG
# Size: (730, 1145)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10131.JPEG
# Format: JPEG
# Size: (331, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9176.JPEG
# Format: JPEG
# Size: (500, 312)
# Mode: RGB
# ------------------------------
# Filename: n02056570_583.JPEG
# Format: JPEG
# Size: (500, 441)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1707.JPEG
# Format: JPEG
# Size: (469, 720)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8374.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3973.JPEG
# Format: JPEG
# Size: (376, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8394.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1322.JPEG
# Format: JPEG
# Size: (500, 332)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1686.JPEG
# Format: JPEG
# Size: (400, 264)
# Mode: RGB
# ------------------------------
# Filename: n02056570_15880.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9795.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2094.JPEG
# Format: JPEG
# Size: (611, 404)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3194.JPEG
# Format: JPEG
# Size: (180, 135)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6452.JPEG
# Format: JPEG
# Size: (464, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2694.JPEG
# Format: JPEG
# Size: (399, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8959.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8989.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9466.JPEG
# Format: JPEG
# Size: (500, 356)
# Mode: RGB
# ------------------------------
# Filename: n02056570_22938.JPEG
# Format: JPEG
# Size: (500, 342)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13255.JPEG
# Format: JPEG
# Size: (500, 372)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6422.JPEG
# Format: JPEG
# Size: (2207, 1502)
# Mode: RGB
# ------------------------------
# Filename: n02056570_791.JPEG
# Format: JPEG
# Size: (725, 484)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1134.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10964.JPEG
# Format: JPEG
# Size: (338, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3540.JPEG
# Format: JPEG
# Size: (500, 380)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1276.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3980.JPEG
# Format: JPEG
# Size: (500, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6328.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9519.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1048.JPEG
# Format: JPEG
# Size: (1600, 1200)
# Mode: RGB
# ------------------------------
# Filename: n02056570_22517.JPEG
# Format: JPEG
# Size: (500, 351)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10135.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10127.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4283.JPEG
# Format: JPEG
# Size: (456, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7204.JPEG
# Format: JPEG
# Size: (600, 399)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7231.JPEG
# Format: JPEG
# Size: (800, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9303.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8202.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8419.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8263.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2842.JPEG
# Format: JPEG
# Size: (541, 360)
# Mode: RGB
# ------------------------------
# Filename: n02056570_22799.JPEG
# Format: JPEG
# Size: (378, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8553.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3406.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5950.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_21871.JPEG
# Format: JPEG
# Size: (500, 357)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1891.JPEG
# Format: JPEG
# Size: (1600, 1031)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8825.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10865.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9055.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7824.JPEG
# Format: JPEG
# Size: (626, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4518.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10110.JPEG
# Format: JPEG
# Size: (500, 387)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8531.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10230.JPEG
# Format: JPEG
# Size: (337, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_15074.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6869.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_18502.JPEG
# Format: JPEG
# Size: (359, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8230.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8875.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_841.JPEG
# Format: JPEG
# Size: (800, 610)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7833.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_41.JPEG
# Format: JPEG
# Size: (612, 690)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9612.JPEG
# Format: JPEG
# Size: (500, 450)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8456.JPEG
# Format: JPEG
# Size: (394, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4258.JPEG
# Format: JPEG
# Size: (640, 465)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3036.JPEG
# Format: JPEG
# Size: (324, 205)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7345.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2653.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13692.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9105.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6351.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7176.JPEG
# Format: JPEG
# Size: (336, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1794.JPEG
# Format: JPEG
# Size: (600, 750)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3631.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7131.JPEG
# Format: JPEG
# Size: (360, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2839.JPEG
# Format: JPEG
# Size: (384, 256)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8227.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1054.JPEG
# Format: JPEG
# Size: (574, 455)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9768.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7421.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9541.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9250.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8321.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9650.JPEG
# Format: JPEG
# Size: (435, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2264.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9268.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8587.JPEG
# Format: JPEG
# Size: (500, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9119.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9390.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13572.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_500.JPEG
# Format: JPEG
# Size: (350, 305)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8490.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8253.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9073.JPEG
# Format: JPEG
# Size: (379, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2524.JPEG
# Format: JPEG
# Size: (600, 354)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5078.JPEG
# Format: JPEG
# Size: (1712, 2153)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8876.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3535.JPEG
# Format: JPEG
# Size: (465, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7609.JPEG
# Format: JPEG
# Size: (750, 492)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1518.JPEG
# Format: JPEG
# Size: (590, 393)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1460.JPEG
# Format: JPEG
# Size: (1024, 685)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3587.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2755.JPEG
# Format: JPEG
# Size: (140, 144)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6202.JPEG
# Format: JPEG
# Size: (2288, 1712)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1603.JPEG
# Format: JPEG
# Size: (120, 90)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9229.JPEG
# Format: JPEG
# Size: (492, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2618.JPEG
# Format: JPEG
# Size: (480, 360)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8789.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8786.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2735.JPEG
# Format: JPEG
# Size: (500, 455)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8797.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_333.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8870.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8411.JPEG
# Format: JPEG
# Size: (500, 394)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9338.JPEG
# Format: JPEG
# Size: (500, 316)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9487.JPEG
# Format: JPEG
# Size: (493, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2974.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_969.JPEG
# Format: JPEG
# Size: (268, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8256.JPEG
# Format: JPEG
# Size: (500, 337)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12660.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11959.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13629.JPEG
# Format: JPEG
# Size: (500, 347)
# Mode: RGB
# ------------------------------
# Filename: n02056570_26297.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1696.JPEG
# Format: JPEG
# Size: (265, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2217.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8762.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10881.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10004.JPEG
# Format: JPEG
# Size: (500, 309)
# Mode: RGB
# ------------------------------
# Filename: n02056570_27055.JPEG
# Format: JPEG
# Size: (355, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10119.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8574.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12502.JPEG
# Format: JPEG
# Size: (500, 392)
# Mode: RGB
# ------------------------------
# Filename: n02056570_42.JPEG
# Format: JPEG
# Size: (600, 800)
# Mode: RGB
# ------------------------------
# Filename: n02056570_551.JPEG
# Format: JPEG
# Size: (600, 403)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1835.JPEG
# Format: JPEG
# Size: (267, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_776.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1202.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6468.JPEG
# Format: JPEG
# Size: (432, 632)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9828.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5278.JPEG
# Format: JPEG
# Size: (411, 420)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9521.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8315.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9767.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9033.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1452.JPEG
# Format: JPEG
# Size: (640, 481)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3729.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6051.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_25917.JPEG
# Format: JPEG
# Size: (500, 360)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1755.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7085.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_26823.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9535.JPEG
# Format: JPEG
# Size: (374, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5577.JPEG
# Format: JPEG
# Size: (1600, 1200)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6007.JPEG
# Format: JPEG
# Size: (430, 430)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7196.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9200.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12798.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7207.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1093.JPEG
# Format: JPEG
# Size: (432, 619)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9381.JPEG
# Format: JPEG
# Size: (331, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8282.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5207.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1895.JPEG
# Format: JPEG
# Size: (472, 944)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5158.JPEG
# Format: JPEG
# Size: (600, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8754.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8626.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9952.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9288.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11927.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7817.JPEG
# Format: JPEG
# Size: (2189, 1598)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6279.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6147.JPEG
# Format: JPEG
# Size: (768, 575)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6296.JPEG
# Format: JPEG
# Size: (500, 456)
# Mode: RGB
# ------------------------------
# Filename: n02056570_252.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1698.JPEG
# Format: JPEG
# Size: (114, 170)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5189.JPEG
# ...
# Filename: n02056570_9761.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10061.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12749.JPEG
# Format: JPEG
# Size: (500, 357)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10054.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8600.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_416.JPEG
# Format: JPEG
# Size: (270, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8644.JPEG
# Format: JPEG
# Size: (500, 368)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2987.JPEG
# Format: JPEG
# Size: (640, 427)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6442.JPEG
# Format: JPEG
# Size: (459, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10248.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9553.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_235.JPEG
# Format: JPEG
# Size: (310, 300)
# Mode: RGB
# ------------------------------
# Filename: n02056570_116.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8259.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10600.JPEG
# Format: JPEG
# Size: (345, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2048.JPEG
# Format: JPEG
# Size: (77, 114)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1536.JPEG
# Format: JPEG
# Size: (1344, 1600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9862.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3318.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4820.JPEG
# Format: JPEG
# Size: (370, 267)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4357.JPEG
# Format: JPEG
# Size: (725, 484)
# Mode: RGB
# ------------------------------
# Filename: n02056570_930.JPEG
# Format: JPEG
# Size: (428, 640)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4131.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11673.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_17409.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_142.JPEG
# Format: JPEG
# Size: (273, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6181.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10068.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7174.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7498.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3502.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_863.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9456.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7377.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8265.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8514.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_197.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1337.JPEG
# Format: JPEG
# Size: (270, 224)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2833.JPEG
# Format: JPEG
# Size: (240, 324)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5255.JPEG
# Format: JPEG
# Size: (500, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6826.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9500.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12599.JPEG
# Format: JPEG
# Size: (500, 374)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9832.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_25491.JPEG
# Format: JPEG
# Size: (360, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2827.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10486.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9883.JPEG
# Format: JPEG
# Size: (500, 498)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3562.JPEG
# Format: JPEG
# Size: (432, 621)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7178.JPEG
# Format: JPEG
# Size: (512, 672)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8498.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3971.JPEG
# Format: JPEG
# Size: (500, 391)
# Mode: RGB
# ------------------------------
# Filename: n02056570_790.JPEG
# Format: JPEG
# Size: (400, 249)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10286.JPEG
# Format: JPEG
# Size: (365, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2479.JPEG
# Format: JPEG
# Size: (484, 725)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9891.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8653.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3244.JPEG
# Format: JPEG
# Size: (150, 226)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9654.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10936.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4215.JPEG
# Format: JPEG
# Size: (676, 507)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5434.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6074.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9328.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8831.JPEG
# Format: JPEG
# Size: (332, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10375.JPEG
# Format: JPEG
# Size: (500, 335)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9512.JPEG
# Format: JPEG
# Size: (500, 372)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9800.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8615.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9479.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6348.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6329.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8384.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11350.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1607.JPEG
# Format: JPEG
# Size: (626, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_737.JPEG
# Format: JPEG
# Size: (725, 484)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2612.JPEG
# Format: JPEG
# Size: (636, 604)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4398.JPEG
# Format: JPEG
# Size: (800, 572)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8313.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13462.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5142.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9496.JPEG
# Format: JPEG
# Size: (500, 374)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7495.JPEG
# Format: JPEG
# Size: (500, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2149.JPEG
# Format: JPEG
# Size: (600, 1120)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9041.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10879.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_184.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12068.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11917.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9515.JPEG
# Format: JPEG
# Size: (401, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9421.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12035.JPEG
# Format: JPEG
# Size: (392, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4321.JPEG
# Format: JPEG
# Size: (600, 399)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7720.JPEG
# Format: JPEG
# Size: (600, 346)
# Mode: RGB
# ------------------------------
# Filename: n02056570_13929.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7138.JPEG
# Format: JPEG
# Size: (500, 346)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8464.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9774.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9366.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6939.JPEG
# Format: JPEG
# Size: (600, 450)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9528.JPEG
# Format: JPEG
# Size: (335, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6478.JPEG
# Format: JPEG
# Size: (500, 407)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9710.JPEG
# Format: JPEG
# Size: (334, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2859.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5368.JPEG
# Format: JPEG
# Size: (450, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10019.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10383.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8478.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1401.JPEG
# Format: JPEG
# Size: (200, 188)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8866.JPEG
# Format: JPEG
# Size: (362, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1798.JPEG
# Format: JPEG
# Size: (338, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_61.JPEG
# Format: JPEG
# Size: (339, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8628.JPEG
# Format: JPEG
# Size: (500, 340)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6185.JPEG
# Format: JPEG
# Size: (800, 600)
# Mode: RGB
# ------------------------------
# Filename: n02056570_5243.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7397.JPEG
# Format: JPEG
# Size: (500, 338)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3572.JPEG
# Format: JPEG
# Size: (400, 300)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1151.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8174.JPEG
# Format: JPEG
# Size: (860, 581)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3186.JPEG
# Format: JPEG
# Size: (469, 720)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4086.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_233.JPEG
# Format: JPEG
# Size: (485, 700)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9369.JPEG
# Format: JPEG
# Size: (500, 313)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9516.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8019.JPEG
# Format: JPEG
# Size: (400, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9689.JPEG
# Format: JPEG
# Size: (500, 474)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8275.JPEG
# Format: JPEG
# Size: (357, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_4645.JPEG
# Format: JPEG
# Size: (640, 480)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9482.JPEG
# Format: JPEG
# Size: (337, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9556.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6326.JPEG
# Format: JPEG
# Size: (388, 640)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3426.JPEG
# Format: JPEG
# Size: (1024, 768)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7504.JPEG
# Format: JPEG
# Size: (887, 591)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12718.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11311.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9859.JPEG
# Format: JPEG
# Size: (500, 354)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2208.JPEG
# Format: JPEG
# Size: (255, 340)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8323.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_870.JPEG
# Format: JPEG
# Size: (333, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_25509.JPEG
# Format: JPEG
# Size: (500, 334)
# Mode: RGB
# ------------------------------
# Filename: n02056570_10101.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2920.JPEG
# Format: JPEG
# Size: (338, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8453.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9195.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_1275.JPEG
# Format: JPEG
# Size: (500, 400)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2881.JPEG
# Format: JPEG
# Size: (500, 333)
# Mode: RGB
# ------------------------------
# Filename: n02056570_8421.JPEG
# Format: JPEG
# Size: (500, 375)
# Mode: RGB
# ------------------------------
# Filename: n02056570_727.JPEG
# Format: JPEG
# Size: (1600, 698)
# Mode: RGB
# ------------------------------
# Filename: n02056570_11921.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7363.JPEG
# Format: JPEG
# Size: (356, 504)
# Mode: RGB
# ------------------------------
# Filename: n02056570_12563.JPEG
# Format: JPEG
# Size: (500, 373)
# Mode: RGB
# ------------------------------
# Filename: n02056570_3292.JPEG
# Format: JPEG
# Size: (375, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2867.JPEG
# Format: JPEG
# Size: (307, 320)
# Mode: RGB
# ------------------------------
# Filename: n02056570_9164.JPEG
# Format: JPEG
# Size: (379, 500)
# Mode: RGB
# ------------------------------
# Filename: n02056570_7715.JPEG
# Format: JPEG
# Size: (714, 499)
# Mode: RGB
# ------------------------------
# Filename: n02056570_2043.JPEG
# Format: JPEG
# Size: (1944, 1296)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6622.JPEG
# Format: JPEG
# Size: (500, 361)
# Mode: RGB
# ------------------------------
# Filename: n02056570_6572.JPEG
# Format: JPEG
# Size: (500, 487)
# Mode: RGB
# ------------------------------
